# %% [markdown]
# * 이 페이지는 실행에 3~5분 정도 소요됩니다.
# * 아래의 코드 블럭 세개를 모두 실행시키면 됩니다.('ctrl+F9'로 실행시키면 한꺼번에 모두 실행됩니다.)
# * Google Colab의 리소스 사정으로 GPU나 TPU를 사용할 수 없을 경우 GPU로 처리하면 되나, 실행시간이 오래 걸릴 수 있습니다(20~30분).
# * 가끔 인터넷 문제로 챗봇 데이터를 로딩하는 과정에서 오류나는 경우가 있습니다.

# %%
# !pip install sentence_transformers

from sentence_transformers import SentenceTransformer

import pandas as pd
from numpy import dot
from numpy.linalg import norm

import urllib.request

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/songys/Chatbot_data/master/ChatbotData.csv", filename="ChatBotData.csv")
train_data = pd.read_csv('ChatBotData.csv')

model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')

train_data['embedding'] = train_data.apply(lambda row: model.encode(row.Q), axis = 1)

def cos_sim(A, B):
  return dot(A, B)/(norm(A)*norm(B))

def return_answer(input):
    embedding = model.encode(input)
    train_data['score'] = train_data.apply(lambda x: cos_sim(x['embedding'], embedding), axis=1)
    return train_data.loc[train_data['score'].idxmax()]['A']

# %%
print("\n\n이 예제는 트랜스포머 모델인 BERT를 사용하여 만든 간단한 챗봇입니다.\n")
print("이 예제는 안상준, 유원준님의 '딥 러닝을 이용한 자연어 처리 입문'의")
print("'18-08 BERT의 문장 임베딩(SBERT)을 이용한 한국어 챗봇'의 예제를 참고하여 만들었습니다.\n\n")

while True:
    text = input("대화를 입력하세요(또는 '/그만'를 입력하여 종료하세요): ")

    if text == '/그만':
        break

    print(return_answer(text))
# Out:
# 이 예제는 트랜스포머 모델인 BERT를 사용하여 만든 간단한 챗봇입니다.
#
# 이 예제는 안상준, 유원준님의 '딥 러닝을 이용한 자연어 처리 입문'의
# '18-08 BERT의 문장 임베딩(SBERT)을 이용한 한국어 챗봇'의 예제를 참고하여 만들었습니다.
#
#
# 대화를 입력하세요(또는 '/그만'를 입력하여 종료하세요): /그만
